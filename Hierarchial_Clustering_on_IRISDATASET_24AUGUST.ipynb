# %% [markdown]
# <a href="https://colab.research.google.com/github/AnshumanMohapatra11121999/Machine-Learning2-7thSem-/blob/main/Hierarchial_Clustering_on_IRISDATASET_24AUGUST.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from scipy.cluster.hierarchy import dendrogram, linkage

# Load the Iris dataset
iris = load_iris()
X = iris.data

# %%
# Perform hierarchical clustering using linkage
Z = linkage(X, 'ward')

# %%
# Create a dendrogram to visualize the hierarchy
plt.figure(figsize=(10, 6))
dendrogram(Z)
plt.xlabel('Sample Index')
plt.ylabel('Distance')
plt.title('Dendrogram for Hierarchical Clustering')
plt.show()

# %%
from scipy.cluster.hierarchy import fcluster

# Cut the dendrogram to obtain clusters
max_d = 7.08  # Adjust this threshold to control the number of clusters
clusters = fcluster(Z, t=max_d, criterion='distance')

# %%
# Visualize the clustered data
plt.scatter(X[:, 0], X[:, 1], c=clusters, cmap='viridis')
plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')
plt.title('Hierarchical Clustering Result')
plt.show()
